# %% [markdown]
# # Direct usage with Notebook

# %%
# Common Libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ## Tests on challenge welding data
#
# This dataset is described on the website of challenge welding : https://confianceai.github.io/Welding-Quality-Detection-Challenge/

# %%
# upload data
# Dataset path
path = "../tests/integration/fixtures/data/challenge_welding.csv"
data = pd.read_csv(path, sep=",")
data
# Out:
#         sample_id class         timestamp welding-seams labelling_type  \
# 0      data_37966    OK  08/07/2022 02:05           c33       operator
# 1      data_25403    OK  19/07/2022 00:51          c102       operator
# 2      data_27038    OK  28/07/2022 16:08          c102       operator
# 3       data_8767    OK    31/01/20 09:41           c33         expert
# 4       data_4744    OK    25/11/19 21:57           c20         expert
# ...           ...   ...               ...           ...            ...
# 22748  data_66456    OK    29/10/19 01:33          c102         expert
# 22749  data_24294    OK  07/07/2022 01:40          c102       operator
# 22750  data_25568    OK  19/07/2022 11:59          c102       operator
# 22751  data_39356    OK  13/07/2022 06:45           c33       operator
# 22752   data_8988    OK    09/03/20 12:22           c33         expert
#
#         resolution                                               path  \
# 0        [960 540]  challenge-welding/datasets/welding-detection-c...
# 1        [960 540]  challenge-welding/datasets/welding-detection-c...
# 2        [960 540]  challenge-welding/datasets/welding-detection-c...
# 3      [1920 1080]  challenge-welding/datasets/welding-detection-c...
# 4      [1920 1080]  challenge-welding/datasets/welding-detection-c...
# ...            ...                                                ...
# 22748  [1920 1080]  challenge-welding/datasets/welding-detection-c...
# 22749    [960 540]  challenge-welding/datasets/welding-detection-c...
# 22750    [960 540]  challenge-welding/datasets/welding-detection-c...
# 22751    [960 540]  challenge-welding/datasets/welding-detection-c...
# 22752  [1920 1080]  challenge-welding/datasets/welding-detection-c...
#
#                                                   sha256 storage_type  \
# 0      b'0F\\\x12\xa1\x81\xcdL\xc3~\xbe\x03\xc90\x91\...           s3
# 1      b'\tlM\xd7\x83\\\x7fm\xaeV\xc6\xbd\xd6S@\x17S\...           s3
# 2      b'\xeb\xba/\xe0-\xe6\x14\xd6\xe0\xf2oT\xd1\xa9...           s3
# 3      b"\x9e@!\xd3\xdd\xaa'\xb7]\xeb\xf7B\x800\xf1\x...           s3
# 4      b'\x0c\xd8\xcfb\x95\\\xb9\xa8w\xe7^\xea\rX,8\x...           s3
# ...                                                  ...          ...
# 22748  b'\x9fZ^\xc5j\xf1\xd8JRw\x03\xa4C\x04\xa6\xa1\...           s3
# 22749  b'\x05\x07x\xa4\xb8\x01\xf1a\x18.\x13\xe4\xe6\...           s3
# 22750  b'O\x0eT\xa1\x8b\xa0\xf5\xaei\x81\xe8\x16\x96p...           s3
# 22751  b'\x1bh\xd9\x8aK\x88\xc1\xcb\xea\xff\xe3]{\x0e...           s3
# 22752  b'\xce\x0e\x87\xd7\x9b\x8d\xc4\x10[\xe9\x8fl\x...           s3
#
#       data_origin   blur_level blur_class  luminosity_level  \
# 0            real  1667.425860      clean         51.079433
# 1            real   868.574712       blur         32.825601
# 2            real  1078.402671      clean         35.192525
# 3            real  1240.198851      clean         38.510588
# 4            real  3371.897144      clean         46.001366
# ...           ...          ...        ...               ...
# 22748        real  4463.079210      clean         41.554284
# 22749        real   859.194594       blur         31.966749
# 22750        real   977.316444      clean         40.872106
# 22751        real  1653.447154      clean         50.429395
# 22752        real   593.528212       blur         39.343171
#
#                                            external_path
# 0      http://minio-storage.apps.confianceai-public.i...
# 1      http://minio-storage.apps.confianceai-public.i...
# 2      http://minio-storage.apps.confianceai-public.i...
# 3      http://minio-storage.apps.confianceai-public.i...
# 4      http://minio-storage.apps.confianceai-public.i...
# ...                                                  ...
# 22748  http://minio-storage.apps.confianceai-public.i...
# 22749  http://minio-storage.apps.confianceai-public.i...
# 22750  http://minio-storage.apps.confianceai-public.i...
# 22751  http://minio-storage.apps.confianceai-public.i...
# 22752  http://minio-storage.apps.confianceai-public.i...
#
# [22753 rows x 14 columns]

# %% [markdown]
# # Completeness
# you can see also the file: *packages/dqm-ml-core/src/dqm_ml_core/metrics/completeness.py*

# %%
from dqm_ml_core import CompletenessProcessor, MetricRunner

# %%
# Compute completeness on the whole dataset
runner = MetricRunner()

metric = CompletenessProcessor(config={"include_per_column": False})
metrics_values = runner.run(data, [metric])
print(metrics_values)
# Out:
# {'completeness_overall': 1.0}

# %%
# Compute completeness on a single column

# Configure column and metric metric name in outdict
metric = CompletenessProcessor(config={"columns": {"input": ["blur_level"]}})
metrics_values = runner.run(data, [metric])

print("Overall Data Completeness Score: ", metrics_values["completeness_overall"])
print("Completeness Score for Column: ", metrics_values["completeness_blur_level"])
# Out:
# Overall Data Completeness Score:  1.0
# Completeness Score for Column:  1.0

# %% [markdown]
# # Representativeness

# %%
# Using the method chisquare_test
from dqm_ml_core import RepresentativenessProcessor

bins = 20
distribution = "normal"

metric = RepresentativenessProcessor(
    config={
        "metrics": ["chi-square"],
        "columns": {"input": ["blur_level"]},
        "histogram": {"bins": 20},
        "distribution": "normal",
    }
)
metrics_values = runner.run(data, [metric])
print(metrics_values)

print("Chi-Square Test: p-value = ", metrics_values["chi-square_blur_level_p_value"])
# Out:
# {'chi-square_blur_level_p_value': 0.0, 'chi-square_blur_level_statistic': 6889.4673252542625, 'chi-square_blur_level_interpretation': 'does_not_follow_distribution', '_metadata': '{"bins": 20, "distribution": "normal", "metrics_computed": ["chi-square"], "total_samples": 22753, "columns_analyzed": ["blur_level"], "ks_sampling_enabled": false, "note": "KS test uses random sampling approximation for scalability"}'}
# Chi-Square Test: p-value =  0.0

# %%
metric = RepresentativenessProcessor(
    config={
        "metrics": ["kolmogorov-smirnov"],
        "columns": {"input": ["blur_level"]},
        "histogram": {"bins": 20},
        "distribution": "normal",
    }
)
metrics_values = runner.run(data, [metric])
print(metrics_values)

print(f"Kolmogorov-Smirnov Test: p-value = ", metrics_values["kolmogorov-smirnov_blur_level_p_value"])
# Out:
# {'kolmogorov-smirnov_blur_level_p_value': 0.0027425888296048, 'kolmogorov-smirnov_blur_level_statistic': 0.08081722251033718, 'kolmogorov-smirnov_blur_level_interpretation': 'does_not_follow_distribution', 'kolmogorov-smirnov_blur_level_sample_size': 500, 'kolmogorov-smirnov_blur_level_note': 'approximated_from_random_samples', '_metadata': '{"bins": 20, "distribution": "normal", "metrics_computed": ["kolmogorov-smirnov"], "total_samples": 22753, "columns_analyzed": ["blur_level"], "ks_sampling_enabled": true, "note": "KS test uses random sampling approximation for scalability"}'}
# Kolmogorov-Smirnov Test: p-value =  0.0027425888296048

# %%
metric = RepresentativenessProcessor(
    config={
        "metrics": ["shannon-entropy"],
        "columns": {"input": ["blur_level"]},
        "histogram": {"bins": 20},
        "distribution": "normal",
    }
)
metrics_values = runner.run(data, [metric])
print(metrics_values)

print(f"Shannon Entropy Test: p-value = ", metrics_values["shannon-entropy_blur_level_entropy"])
# Out:
# {'shannon-entropy_blur_level_entropy': 0.0, 'shannon-entropy_blur_level_interpretation': 'low_diversity', '_metadata': '{"bins": 20, "distribution": "normal", "metrics_computed": ["shannon-entropy"], "total_samples": 22753, "columns_analyzed": ["blur_level"], "ks_sampling_enabled": false, "note": "KS test uses random sampling approximation for scalability"}'}
# Shannon Entropy Test: p-value =  0.0

# %%
metric = RepresentativenessProcessor(
    config={
        "metrics": ["grte"],
        "columns": {"input": ["blur_level"]},
        "histogram": {"bins": 20},
        "distribution": "normal",
    }
)
metrics_values = runner.run(data, [metric])
print(metrics_values)

print(f"GRTE = ", metrics_values["grte_blur_level_grte_value"])
# Out:
# {'grte_blur_level_grte_value': 0.0033471687739706863, 'grte_blur_level_interpretation': 'low_representativeness', '_metadata': '{"bins": 20, "distribution": "normal", "metrics_computed": ["grte"], "total_samples": 22753, "columns_analyzed": ["blur_level"], "ks_sampling_enabled": false, "note": "KS test uses random sampling approximation for scalability"}'}
# GRTE =  0.0033471687739706863

# %% [markdown]
# # We can compute all metrics at once

# %%
metric = RepresentativenessProcessor(
    config={"columns": {"input": ["blur_level"]}, "histogram": {"bins": 20}, "distribution": "normal"}
)
metrics_values = runner.run(data, [metric])
print(metrics_values)
# Out:
# {'chi-square_blur_level_p_value': 0.0, 'chi-square_blur_level_statistic': 6836.63466160712, 'chi-square_blur_level_interpretation': 'does_not_follow_distribution', 'kolmogorov-smirnov_blur_level_p_value': 0.0005331732342191227, 'kolmogorov-smirnov_blur_level_statistic': 0.0903229853268448, 'kolmogorov-smirnov_blur_level_interpretation': 'does_not_follow_distribution', 'kolmogorov-smirnov_blur_level_sample_size': 500, 'kolmogorov-smirnov_blur_level_note': 'approximated_from_random_samples', 'shannon-entropy_blur_level_entropy': 2.992156268257924, 'shannon-entropy_blur_level_interpretation': 'high_diversity', 'grte_blur_level_grte_value': 0.7522608772627367, 'grte_blur_level_interpretation': 'high_representativeness', '_metadata': '{"bins": 20, "distribution": "normal", "metrics_computed": ["chi-square", "grte", "kolmogorov-smirnov", "shannon-entropy"], "total_samples": 22753, "columns_analyzed": ["blur_level"], "ks_sampling_enabled": true, "note": "KS test uses random sampling approximation for scalability"}'}
